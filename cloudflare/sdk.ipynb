# %%
import os
from cloudflare import Cloudflare

client = Cloudflare(
    api_email=os.environ.get("CLOUDFLARE_EMAIL"),  # This is the default and can be omitted
    api_key=os.environ.get("CLOUDFLARE_API_KEY"),  # This is the default and can be omitted
)
domain = client.pages.projects.domains.create(
    project_name="this-is-my-project-01",
    account_id="023e105f4ecef8ad9ca31a8372d0c353",
)
print(domain.id)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       2 from cloudflare import Cloudflare
#       4 client = Cloudflare(
#       5     api_email=os.environ.get("CLOUDFLARE_EMAIL"),  # This is the default and can be omitted
#       6     api_key=os.environ.get("CLOUDFLARE_API_KEY"),  # This is the default and can be omitted
#       7 )
# ----> 8 domain = client.pages.projects.domains.create(
#       9     project_name="this-is-my-project-01",
#      10     account_id="023e105f4ecef8ad9ca31a8372d0c353",
#      11 )
#      12 print(domain.id)
#
# TypeError: DomainsResource.create() missing 1 required keyword-only argument: 'body'
